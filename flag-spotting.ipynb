# %%
import sys #Imports sys, this module allows access to variables used by the interpreter.
import pandas as pd #Imports pandas.
import matplotlib.pyplot as plt #Imports matplotlib
# %matplotlib inline

flags_df = pd.read_csv("flags.csv") #Using pandas to read the flags.csv file.

print(flags_df.to_string()) #Prints the flags.csv file.
# Out:
#                                                                                                                     Flag  Total    Image?  27443
# 0                                                                      Luxembourg (royal wedding, see Luxembourg folder)     13  No image    NaN
# 1                                                            Glory to Ukraine Lithuania is with you (see Vilnius folder)      2  No image    NaN
# 2                                           Holland (orange with two black horses, says Holland in white bold at bottom)      2  No image    NaN
# 3                                                            Barcelona F. C. (see Madrid folder, with 'CHAMPIONS' on it)      1  No image    NaN
# 4                                                                                    Bideford Victoria Park Bowling Club      1  No image    NaN
# ...

# %%
flags_df.head(5) #Displays the first five records.
# Out:
#                                                 Flag  Total    Image?  27443
# 0  Luxembourg (royal wedding, see Luxembourg folder)     13  No image    NaN
# 1  Glory to Ukraine Lithuania is with you (see Vi...      2  No image    NaN
# 2  Holland (orange with two black horses, says Ho...      2  No image    NaN
# 3  Barcelona F. C. (see Madrid folder, with 'CHAM...      1  No image    NaN
# 4                Bideford Victoria Park Bowling Club      1  No image    NaN

# %%
flags_df.tail(5) #Displays the last five records.
# Out:
#                                                   Flag  Total Image?  27443
# 871                  Vojvodina (traditional, vertical)      1    NaN    NaN
# 872                                  Wartau (vertical)      1    NaN    NaN
# 873                                             Yellow      1    NaN    NaN
# 874                                Yellow (motorsport)      1    NaN    NaN
# 875  Zürich (vertical hanging, with coat of arms at...      1    NaN    NaN

# %%
flags_df.shape #Finds the shape of the DataFrame (rows x columns).
# Out:
# (876, 4)

# %%
flags_df.info() #Gives information on the DataFrame such as the Dtype (data type).
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 876 entries, 0 to 875
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Flag    876 non-null    object
#  1   Total   876 non-null    int64
#  2   Image?  10 non-null     object
#  3   27443   0 non-null      float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 27.5+ KB

# %%
pd.options. display.max_rows = 9999999 #The number of rows to be displayed is set by default to 60, this number can be increased with this line of code.

# %%
new_flags_df = flags_df.dropna() #Creats a new empty DataFrame with the same column headers as flags_df.

print(new_flags_df.to_string())
# Out:
# Empty DataFrame
# Columns: [Flag, Total, Image?, 27443]
# Index: []

# %%
mean_x = flags_df["Total"].mean() #Finds the mean of the total column.

print(mean_x)
# Out:
# 31.327625570776256

# %%
median_x = flags_df["Total"].median() #Finds the median of the total column.

print(median_x)
# Out:
# 3.0

# %%
mode_x = flags_df["Total"].mode()[0] #Finds the mode of the total column.

print(mode_x)
# Out:
# 1

# %%
if 'UK' in new_flags_df['Flag']: #Note change 'new_flags_df' to 'flags_df' for this to work.
    new_flags_df.drop(x, inplace = True) #All of the rows above and including the UK are deleted.
print(new_flags_df.to_string())
# Out:
# Empty DataFrame
# Columns: [Flag, Total, Image?, 27443]
# Index: []

# %%
print(flags_df.duplicated()) #Returns 'True' or 'False' for each row to indicate if they are duplicated or not.
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# ...

# %%
flags_df.drop_duplicates(inplace = True) #This removes any duplicate rows.

# %%
flags_df.corr() #Shows any correlations if they exist. Total has a value of 1.0 as it is the same as itself.

# %%
flags_df.plot() #Creates a plot from the CSV file.
# Out:
# <AxesSubplot:>

# %%
flags_df.plot(kind = 'scatter', x = 'Flag', y = 'Total') #Defines a scatter plot, the axis titles have to be in the CSV file.

plt.show() #Shows the plot.

# %%
flags_df['Total'].plot(kind ='hist') #Creates a histogram for the number of flags which appear one time, two times, three times etc.
# Out:
# <AxesSubplot:ylabel='Frequency'>
